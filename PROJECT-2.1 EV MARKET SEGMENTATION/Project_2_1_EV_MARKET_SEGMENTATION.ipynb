# %% [markdown]
# IMPORT LIBRARIES

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.cluster import KMeans

# %% [markdown]
# DATA PREPROCESSING

# %%
dataset1 = pd.read_csv("/content/3_ev_market_india_dataset.csv")
dataset2 = pd.read_csv("/content/EV Stats-1.csv")
dataset3 = pd.read_csv("/content/EV_Customer_preferences.csv")

# %%
# Check for missing values in dataset 1
print("Missing values in Dataset 1:")
print(dataset1.isnull().sum())

# Check for missing values in dataset 2
print("\nMissing values in Dataset 2:")
print(dataset2.isnull().sum())

# Check for missing values in dataset 3
print("\nMissing values in Dataset 3:")
print(dataset3.isnull().sum())
# Out:
# Missing values in Dataset 1:
# Brand              0
# Model              0
# AccelSec           0
# TopSpeed_KmH       0
# Range_Km           0
# Efficiency_WhKm    0
# FastCharge_KmH     0
# RapidCharge        0
# PowerTrain         0
# PlugType           0
# BodyStyle          0
# Segment            0
# Seats              0
# Price INR          0
# dtype: int64
#
# Missing values in Dataset 2:
# Sl. No                                                                1
# State                                                                 1
# Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules    4
# Two Wheelers (Category L2 (CMVR))                                     4
# Two Wheelers (Max power not exceeding 250 Watts)                      4
# Three Wheelers (Category L5 slow speed as per CMVR)                   1
# Three Wheelers (Category L5 as per CMVR)                              4
# Passenger Cars (Category M1 as per CMVR)                              4
# ...

# %%
dataset3.head()
# Out:
#    Unnamed: 0  Age  City  Profession  Marital Status  Education  \
# 0           0   30    18           2               1          0
# 1           1   27    26           2               1          0
# 2           2   32    15           2               1          0
# 3           3   55    26           0               1          0
# 4           4   26    29           2               1          0
#
#    No. of Family members  Annual Income  \
# 0                      5   1.193876e+06
# 1                      4   1.844540e+06
# 2                      4   2.948150e+06
# 3                      3   2.832380e+06
# 4                      4   2.638751e+06
#
#    Would you prefer replacing all your vehicles to Electronic vehicles?  \
# 0                                                  0
# 1                                                  2
# 2                                                  2
# 3                                                  0
# ...

# %%
dataset2 = dataset2.drop(range(31, 35))

# %%
print(dataset2.isnull().sum())
# Out:
# Sl. No                                                                0
# State                                                                 0
# Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules    0
# Two Wheelers (Category L2 (CMVR))                                     0
# Two Wheelers (Max power not exceeding 250 Watts)                      0
# Three Wheelers (Category L5 slow speed as per CMVR)                   0
# Three Wheelers (Category L5 as per CMVR)                              0
# Passenger Cars (Category M1 as per CMVR)                              0
# Buses                                                                 0
# Total in state                                                        0
# dtype: int64

# %%
dataset3.fillna('Unknown', inplace=True)

# %%
# Check for missing values in dataset 1
print("Missing values in Dataset 1:")
print(dataset1.isnull().sum())

# Check for missing values in dataset 2
print("\nMissing values in Dataset 2:")
print(dataset2.isnull().sum())

# Check for missing values in dataset 3
print("\nMissing values in Dataset 3:")
print(dataset3.isnull().sum())
# Out:
# Missing values in Dataset 1:
# Brand              0
# Model              0
# AccelSec           0
# TopSpeed_KmH       0
# Range_Km           0
# Efficiency_WhKm    0
# FastCharge_KmH     0
# RapidCharge        0
# PowerTrain         0
# PlugType           0
# BodyStyle          0
# Segment            0
# Seats              0
# Price INR          0
# dtype: int64
#
# Missing values in Dataset 2:
# Sl. No                                                                0
# State                                                                 0
# Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules    0
# Two Wheelers (Category L2 (CMVR))                                     0
# Two Wheelers (Max power not exceeding 250 Watts)                      0
# Three Wheelers (Category L5 slow speed as per CMVR)                   0
# Three Wheelers (Category L5 as per CMVR)                              0
# Passenger Cars (Category M1 as per CMVR)                              0
# ...

# %%
print("\nData types in Dataset 1:")
print(dataset1.dtypes)
# Out:
# Data types in Dataset 1:
# Brand               object
# Model               object
# AccelSec           float64
# TopSpeed_KmH         int64
# Range_Km             int64
# Efficiency_WhKm      int64
# FastCharge_KmH       int64
# RapidCharge         object
# PowerTrain          object
# PlugType            object
# BodyStyle           object
# Segment             object
# Seats                int64
# Price INR            int64
# dtype: object

# %%
print("\nData types in Dataset 2:")
print(dataset2.dtypes)
# Out:
# Data types in Dataset 2:
# Sl. No                                                                 object
# State                                                                  object
# Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules    float64
# Two Wheelers (Category L2 (CMVR))                                     float64
# Two Wheelers (Max power not exceeding 250 Watts)                      float64
# Three Wheelers (Category L5 slow speed as per CMVR)                    object
# Three Wheelers (Category L5 as per CMVR)                              float64
# Passenger Cars (Category M1 as per CMVR)                              float64
# Buses                                                                 float64
# Total in state                                                        float64
# dtype: object

# %%
print("\nData types in Dataset 3:")
print(dataset3.dtypes)
# Out:
# Data types in Dataset 3:
# Unnamed: 0                                                                int64
# Age                                                                       int64
# City                                                                     object
# Profession                                                               object
# Marital Status                                                           object
# Education                                                                object
# No. of Family members                                                     int64
# Annual Income                                                           float64
# Would you prefer replacing all your vehicles to Electronic vehicles?     object
# If Yes/Maybe what type of  EV would you prefer?                          object
# Do you think Electronic Vehicles are economical?                         object
# ...

# %% [markdown]
# # EXPLORATORY DATA ANALYIS

# %% [markdown]
# DESCRIPTIVE STATISTICS
#
# ---

# %%
# Summary statistics for numerical columns in each dataset
print("Summary Statistics for Dataset 1:")
print(dataset1.describe())

print("\nSummary Statistics for Dataset 2:")
print(dataset2.describe())

print("\nSummary Statistics for Dataset 3:")
print(dataset3.describe())
# Out:
# Summary Statistics for Dataset 1:
#          AccelSec  TopSpeed_KmH    Range_Km  Efficiency_WhKm  FastCharge_KmH  \
# count  103.000000    103.000000  103.000000       103.000000      103.000000
# mean     7.396117    179.194175  338.786408       189.165049      444.271845
# std      3.017430     43.573030  126.014444        29.566839      203.949253
# min      2.100000    123.000000   95.000000       104.000000      170.000000
# 25%      5.100000    150.000000  250.000000       168.000000      260.000000
# 50%      7.300000    160.000000  340.000000       180.000000      440.000000
# 75%      9.000000    200.000000  400.000000       203.000000      555.000000
# max     22.400000    410.000000  970.000000       273.000000      940.000000
#
#             Seats     Price INR
# count  103.000000  1.030000e+02
# mean     4.883495  4.632360e+06
# std      0.795834  2.833177e+06
# min      2.000000  1.670707e+06
# 25%      5.000000  2.857648e+06
# 50%      5.000000  3.735000e+06
# ...

# %% [markdown]
# DATA VISUALIZATION

# %%
# Histogram of Age Distribution
plt.figure(figsize=(10, 6))
plt.hist(dataset3['Age'], bins=10, color='skyblue', edgecolor='black')
plt.title('Age Distribution of Customers')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# Summary statistics
age_summary = dataset3['Age'].describe()
print(age_summary)
# Out:
# count    1000.000000
# mean       31.800000
# std        11.294847
# min        15.000000
# 25%        26.000000
# 50%        29.000000
# 75%        31.000000
# max       118.000000
# Name: Age, dtype: float64

# %% [markdown]
# Most of the Vehicle owner's age are between 20 - 40 years

# %%
# Histogram of Annual Income
plt.hist(dataset3['Annual Income'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Annual Income')
plt.xlabel('Annual Income')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# We can observe that average annual income lies between 20 - 30 lakhs per annum

# %%
# Distribution of Preferences for Replacing Vehicles
plt.figure(figsize=(10, 6))
dataset3['Would you prefer replacing all your vehicles to Electronic vehicles?'].value_counts().plot(kind='bar', color='coral')
plt.title('Preference for Replacing Vehicles with EVs')
plt.xlabel('Preference')
plt.ylabel('Count')
plt.show()

# Summary
preferences_summary = dataset3['Would you prefer replacing all your vehicles to Electronic vehicles?'].value_counts()
print(preferences_summary)
# Out:
# Would you prefer replacing all your vehicles to Electronic vehicles?
# Yes      663
# Maybe    201
# No       136
# Name: count, dtype: int64

# %% [markdown]
# Most of the people are willing to switch to EV, which is a good sign

# %%
# Count the frequency of each EV type
ev_type_counts = dataset3["If Yes/Maybe what type of  EV would you prefer?"].value_counts()

# Plotting the bar chart
plt.figure(figsize=(10, 6))
ev_type_counts.plot(kind='bar', color='skyblue')
plt.title('Preference for Type of Electric Vehicle (EV)')
plt.xlabel('Type of EV')
plt.ylabel('Number of Respondents')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# We can observe that most of the owners want to switch to EV SUV

# %%
# Distribution of Economic Perception of EVs
plt.figure(figsize=(10, 6))
dataset3['Do you think Electronic Vehicles are economical?'].value_counts().plot(kind='bar', color='orange')
plt.title('Perception of EVs as Economical')
plt.xlabel('Opinion')
plt.ylabel('Count')
plt.show()

# Summary
economical_summary = dataset3['Do you think Electronic Vehicles are economical?'].value_counts()
print(economical_summary)
# Out:
# Do you think Electronic Vehicles are economical?
# Yes      768
# Maybe    123
# No       109
# Name: count, dtype: int64

# %% [markdown]
# Owners agree that EV vehicles are budget friendly

# %%
# Distribution of Budget for EV
plt.figure(figsize=(10, 6))
dataset3['How much money could you spend on an Electronic vehicle?'].value_counts().plot(kind='bar', color='blue')
plt.title('Budget for Electric Vehicles')
plt.xlabel('Budget Range')
plt.ylabel('Count')
plt.show()

# Summary
budget_summary = dataset3['How much money could you spend on an Electronic vehicle?'].value_counts()
print(budget_summary)
# Out:
# How much money could you spend on an Electronic vehicle?
# <15 lakhs    483
# <5 lakhs     288
# <25 lakhs    148
# >25 lakhs     34
# 1200000       14
# 2000000       12
# 1500000       11
# 700000        10
# Name: count, dtype: int64

# %% [markdown]
# Most of the owners are ready to spend near to 15 lakhs

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=dataset3, x='Which brand of vehicle do you currently own?', hue='Would you prefer replacing all your vehicles to Electronic vehicles?')
plt.title('Brand Ownership and EV Adoption Preference')
plt.xlabel('Current Vehicle Brand')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Preference')
plt.show()

# %% [markdown]
# DATASET 2

# %%
dataset2_filtered = dataset2[dataset2['State'] != 'Total']

# Plot total vehicles by state using the 'Total in state' column
plt.figure(figsize=(12, 8))
plt.bar(dataset2_filtered['State'], dataset2_filtered['Total in state'], color='skyblue')
plt.xticks(rotation=90)
plt.xlabel('State')
plt.ylabel('Total Vehicles')
plt.title('Total Vehicles by State (Excluding Total)')
plt.show()

# %% [markdown]
# Maharashtra has the most number of Electric Vehicles, followed by Gujarat

# %%
# Plot distribution of each vehicle category (excluding "Total")
vehicle_categories = [
    'Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules',
    'Two Wheelers (Category L2 (CMVR))',
    'Two Wheelers (Max power not exceeding 250 Watts)',
    'Three Wheelers (Category L5 slow speed as per CMVR)',
    'Three Wheelers (Category L5 as per CMVR)',
    'Passenger Cars (Category M1 as per CMVR)',
    'Buses'
]

plt.figure(figsize=(20, 20))
for i, category in enumerate(vehicle_categories):
    plt.subplot(2, 4, i+1)
    plt.bar(dataset2_filtered['State'], dataset2_filtered[category], color='skyblue')
    plt.xticks(rotation=90)
    plt.title(category)
    plt.xlabel('State')
    plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %%
# Identify the top state for each vehicle category (excluding "Total")
for category in vehicle_categories:
    top_state = dataset2_filtered.loc[dataset2_filtered[category].idxmax()]
    print(f"Top state for {category}: {top_state['State']} with {top_state[category]} vehicles")
# Out:
# Top state for Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules: Gujarat with 7182.0 vehicles
# Top state for Two Wheelers (Category L2 (CMVR)): Uttar Pradesh with 2355.0 vehicles
# Top state for Two Wheelers (Max power not exceeding 250 Watts): Uttar Pradesh with 15199.0 vehicles
# Top state for Three Wheelers (Category L5 slow speed as per CMVR): Jharkhand with 9 vehicles
# Top state for Three Wheelers (Category L5 as per CMVR): Uttar Pradesh with 139.0 vehicles
# Top state for Passenger Cars (Category M1 as per CMVR): Maharashtra with 19129.0 vehicles
# Top state for Buses: Delhi with 21.0 vehicles

# %% [markdown]
# DATASET 3
#
# ---

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(data=dataset1, x='AccelSec', y='Price INR', hue='BodyStyle', palette='tab10')
plt.title('Acceleration vs Price of EVs')
plt.xlabel('Acceleration (0-100 km/h in seconds)')
plt.ylabel('Price (INR)')
plt.legend(title='Body Style', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# CLUSTERING
#
#
# ---

# %%
label_encoders = {}
categorical_features = ['City', 'Profession', 'Marital Status', 'Education', 'Would you prefer replacing all your vehicles to Electronic vehicles?',
                         'If Yes/Maybe what type of  EV would you prefer?', 'Do you think Electronic Vehicles are economical?',
                         'Which brand of vehicle do you currently own?', 'Preference for wheels in EV','How much money could you spend on an Electronic vehicle?',
                         'Do you think Electronic vehicles will replace fuel cars in India?']

# %%
for feature in categorical_features:
    if feature in dataset3.columns:
        le = LabelEncoder()
        dataset3[feature] = le.fit_transform(dataset3[feature])
        label_encoders[feature] = le
    else:
        print(f"Column '{feature}' is missing from the DataFrame.")

# %%
# Select relevant features
features = dataset3[['Age', 'City', 'Profession', 'Marital Status', 'Education', 'No. of Family members', 'Annual Income',
                 'Would you prefer replacing all your vehicles to Electronic vehicles?', 'If Yes/Maybe what type of  EV would you prefer?',
                 'Do you think Electronic Vehicles are economical?', 'Which brand of vehicle do you currently own?',
                 'Preference for wheels in EV',
                 'Do you think Electronic vehicles will replace fuel cars in India?']]

# %%
# Normalize the data
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# %%
# Determine the optimal number of clusters using the Elbow Method
inertia = []
k_range = range(1, 11)  # Testing k values from 1 to 10
for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=0)
    kmeans.fit(scaled_features)
    inertia.append(kmeans.inertia_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
# Plot the Elbow graph
plt.figure(figsize=(8, 6))
plt.plot(k_range, inertia, marker='o')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia')
plt.title('Elbow Method for Optimal k')
plt.show()

# %%
optimal_k = 5
kmeans = KMeans(n_clusters=optimal_k, random_state=0)
clusters = kmeans.fit_predict(scaled_features)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
dataset3['Cluster'] = clusters

# %%
# Calculate the mean values of features for each cluster
cluster_summary = dataset3.groupby('Cluster').mean()
print(cluster_summary)
# Out:
#          Unnamed: 0        Age       City  Profession  Marital Status  \
# Cluster
# 0        504.320611  29.740458   5.717557    1.931298        0.595420
# 1        517.914474  29.710526  23.513158    1.796053        0.598684
# 2        486.952854  27.677419  25.235732    2.131514        0.677419
# 3        511.846154  28.298077  24.331731    1.846154        0.620192
# 4        490.613208  59.886792  22.801887    1.849057        0.632075
#
#          Education  No. of Family members  Annual Income  \
# Cluster
# 0         0.312977               3.961832   2.097141e+06
# 1         0.256579               3.835526   2.403335e+06
# 2         0.339950               4.126551   2.280725e+06
# 3         0.293269               4.365385   2.207792e+06
# 4         0.273585               4.198113   2.275734e+06
#
#          Would you prefer replacing all your vehicles to Electronic vehicles?  \
# Cluster
# 0                                                 1.610687
# ...

# %% [markdown]
# Summary:<br>•	Cluster 0 (Moderate Income, Positive EV Perception): This segment consists of individuals with moderate income who have a positive perception of EVs' economic benefits. They prefer a variety of EV types, including SUVs, and are open to spending a reasonable budget on EVs. This group is ideal for marketing mid-range EV models with a focus on value and versatility.<br>
# •	Cluster 1 (High Income, Low Perception of EV Economy): This cluster includes high-income individuals who have a strong preference for SUVs but perceive EVs as less economical. Despite their significant budget for EVs, their low perception of economic benefits might require strategies to highlight cost-efficiency and long-term savings.<br>
# •	Cluster 2 (Young, High Income, Positive EV Perception): Comprising younger individuals with high income, this segment shows a strong preference for EVs and a positive view of their economic benefits. They also have a substantial budget for EVs and prefer SUVs. Marketing strategies for this group should emphasize cutting-edge features and performance.<br>
# •	Cluster 3 (Moderate Income, Low EV Preference): This cluster consists of individuals with a moderate income and a lower preference for EVs. Although they have a good budget for EVs, they are less inclined to switch. Targeted marketing should focus on demonstrating the long-term benefits and addressing their specific concerns to increase adoption.<br>
# •	Cluster 4 (Older Demographic, Moderate Interest in EVs): This segment includes older individuals with moderate income and budget for EVs. They have a positive view of EVs but show a lower preference for switching. Strategies for this group should highlight ease of use and practical benefits, addressing their unique needs and preferences.
